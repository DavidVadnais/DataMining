# %%
# Out:
# ERROR: unknown command "upgrade"

# %%
import numpy as np
import csv
import pandas
from sklearn import tree
import pydotplus
from sklearn.tree import DecisionTreeClassifier
import matplotlib.pyplot as plt
import matplotlib.image as pltimg

from pydotplus import graph_from_dot_data
from IPython.display import Image 
from six import StringIO 
from sklearn.tree import export_graphviz
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

# %%
training_file = 'dataSplit/credit_trainset.txt'
test_file = 'dataSplit/credit_testset.txt'

training_file = 'dataSplit/census_trainset.txt'
test_file = 'dataSplit/census_testset.txt'

# %%
df = pandas.read_csv(training_file, header=None)

print(df)
# Out:
#        0                  1       2              3   4                    5   \
# 0      33          Local-gov  198183      Bachelors  13        Never-married
# 1      36            Private   86459      Assoc-voc  11   Married-civ-spouse
# 2      58   Self-emp-not-inc  203039            9th   5            Separated
# 3      45          State-gov  231013      Bachelors  13             Divorced
# 4      27            Private  279872   Some-college  10             Divorced
# ...    ..                ...     ...            ...  ..                  ...
# 26043  47            Private  359461      Bachelors  13   Married-civ-spouse
# 26044  31            Private  147215           12th   8             Divorced
# 26045  18            Private  216284           11th   7        Never-married
# 26046  50   Self-emp-not-inc   54261        HS-grad   9   Married-civ-spouse
# 26047  34       Self-emp-inc  127651      Bachelors  13             Divorced
#
#                      6               7       8        9   10    11  12  \
# 0        Prof-specialty   Not-in-family   White   Female   0     0  50
# 1       Exec-managerial         Husband   White     Male   0  1887  50
# 2          Craft-repair   Not-in-family   White     Male   0     0  40
# 3       Protective-serv   Not-in-family   White     Male   0     0  40
# 4         Other-service   Not-in-family   White     Male   0     0  40
# ...                 ...             ...     ...      ...  ..   ...  ..
# 26043      Craft-repair         Husband   White     Male   0     0  40
# 26044     Other-service       Unmarried   White   Female   0     0  21
# 26045      Adm-clerical       Own-child   White   Female   0     0  20
# 26046   Farming-fishing         Husband   White     Male   0     0  84
# 26047   Farming-fishing   Not-in-family   White     Male   0     0  60
#
#                    13      14
# 0       United-States    >50K
# 1       United-States    >50K
# 2       United-States   <=50K
# 3       United-States   <=50K
# 4       United-States   <=50K
# ...               ...     ...
# 26043   United-States   <=50K
# 26044   United-States   <=50K
# 26045   United-States   <=50K
# 26046   United-States   <=50K
# 26047   United-States   <=50K
#
# [26048 rows x 15 columns]

# %%
x=df.iloc[: , 0:-2]
y=df.iloc[: , -1]

# %%
x
# Out:
#        0                  1       2              3   4                    5   \
# 0      33          Local-gov  198183      Bachelors  13        Never-married
# 1      36            Private   86459      Assoc-voc  11   Married-civ-spouse
# 2      58   Self-emp-not-inc  203039            9th   5            Separated
# 3      45          State-gov  231013      Bachelors  13             Divorced
# 4      27            Private  279872   Some-college  10             Divorced
# ...    ..                ...     ...            ...  ..                  ...
# 26043  47            Private  359461      Bachelors  13   Married-civ-spouse
# 26044  31            Private  147215           12th   8             Divorced
# 26045  18            Private  216284           11th   7        Never-married
# 26046  50   Self-emp-not-inc   54261        HS-grad   9   Married-civ-spouse
# 26047  34       Self-emp-inc  127651      Bachelors  13             Divorced
#
#                      6               7       8        9   10    11  12
# 0        Prof-specialty   Not-in-family   White   Female   0     0  50
# 1       Exec-managerial         Husband   White     Male   0  1887  50
# 2          Craft-repair   Not-in-family   White     Male   0     0  40
# 3       Protective-serv   Not-in-family   White     Male   0     0  40
# 4         Other-service   Not-in-family   White     Male   0     0  40
# ...                 ...             ...     ...      ...  ..   ...  ..
# 26043      Craft-repair         Husband   White     Male   0     0  40
# 26044     Other-service       Unmarried   White   Female   0     0  21
# 26045      Adm-clerical       Own-child   White   Female   0     0  20
# 26046   Farming-fishing         Husband   White     Male   0     0  84
# 26047   Farming-fishing   Not-in-family   White     Male   0     0  60
#
# [26048 rows x 13 columns]

# %%
#make data numeric
xn = x.to_numpy()

newArray = []

for col in range(len(x.columns)):
    tmpCol = []
    #n = col
    for value in range(len(xn)):
        s = str(xn[value][col]).lower()
        tmpCol.append(hash(s))
    
    newArray.append(tmpCol)

X = pandas.DataFrame({'0': newArray[0]})
features = ['0']
for i in range(len(x.columns)):
    if (i==0):
        continue
    X.insert(loc=i, column=str(i), value=newArray[i])
    features.append(str(i))
    
#DO Y
yn = y.to_numpy()

#tmpCol = []
#for value in range(len(yn)):
#    s = str(yn[value])
#    tmpCol.append(hash(s.lower()))
d = dict([(ytmp,xtmp+1) for xtmp,ytmp in enumerate(sorted(set(yn[:])))])
tmpCol = [d[xtmp] for xtmp in yn[:]]
Y = pandas.DataFrame({'0': tmpCol})

# %%
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, Y)

# %%
df = pandas.read_csv('dataSplit/credit_testset.txt', header=None)

x=df.iloc[: , 0:-2]
y=df.iloc[: , -1]
#make data numeric
xn = x.to_numpy()

newArray = []

for col in range(len(x.columns)):
    tmpCol = []
    #n = col
    for value in range(len(xn)):
        s = str(xn[value][col])
        tmpCol.append(hash(s.lower()))
        
    newArray.append(tmpCol)

X_test = pandas.DataFrame({'0': newArray[0]})
features = ['0']
for i in range(len(x.columns)):
    if (i==0):
        continue
    X_test.insert(loc=i, column=str(i), value=newArray[i])
    features.append(str(i))
    
#DO Y
yn = y.to_numpy()

#tmpCol = []
#for value in range(len(yn)):
#    s = str(yn[value])
#    tmpCol.append(hash(s.lower()))
tmpCol = [d[xtmp] for xtmp in yn[:]]
Y_test = pandas.DataFrame({'0': tmpCol})
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-56-7bc1fddaf6cc> in <module>
#      32 #    s = str(yn[value])
#      33 #    tmpCol.append(hash(s.lower()))
# ---> 34 tmpCol = [d[xtmp] for xtmp in yn[:]]
#      35 Y_test = pandas.DataFrame({'0': tmpCol})
#
# <ipython-input-56-7bc1fddaf6cc> in <listcomp>(.0)
#      32 #    s = str(yn[value])
#      33 #    tmpCol.append(hash(s.lower()))
# ---> 34 tmpCol = [d[xtmp] for xtmp in yn[:]]
#      35 Y_test = pandas.DataFrame({'0': tmpCol})
#
# KeyError: '-'

# %%
y_pred = dtree.predict(X_test)
confusion_matrix(Y_test, y_pred)
# Out:
# array([[70,  0],
#        [ 0, 68]])

# %%
True
# Out:
# True

# %%
val_list = list(d.values())
key_list = list(d.keys())
Y_test_np = Y_test.to_numpy()
misslabeled=0
for i in range(len(y_pred)):
    thisid = i+1
    thispred = key_list[val_list.index(y_pred[i])]
    thisTruth = key_list[val_list.index(Y_test_np[i])]
    if(y_pred[i] != Y_test_np[i]):
        misslabeled += 1
    acc = (thisid-misslabeled)/thisid
    print('ID='+str(thisid)+", predicted="+thispred+", true="+thisTruth \
          +", accuracy="+str(acc))
# Out:
# ID=1, predicted=-, true=-, accuracy=1.0
# ID=2, predicted=+, true=+, accuracy=1.0
# ID=3, predicted=-, true=-, accuracy=1.0
# ID=4, predicted=-, true=-, accuracy=1.0
# ID=5, predicted=+, true=+, accuracy=1.0
# ID=6, predicted=+, true=+, accuracy=1.0
# ID=7, predicted=-, true=-, accuracy=1.0
# ID=8, predicted=+, true=+, accuracy=1.0
# ID=9, predicted=-, true=-, accuracy=1.0
# ID=10, predicted=-, true=-, accuracy=1.0
# ID=11, predicted=-, true=-, accuracy=1.0
# ID=12, predicted=+, true=+, accuracy=1.0
# ID=13, predicted=+, true=+, accuracy=1.0
# ID=14, predicted=-, true=-, accuracy=1.0
# ID=15, predicted=-, true=-, accuracy=1.0
# ID=16, predicted=+, true=+, accuracy=1.0
# ID=17, predicted=-, true=-, accuracy=1.0
# ID=18, predicted=-, true=-, accuracy=1.0
# ID=19, predicted=-, true=-, accuracy=1.0
# ID=20, predicted=-, true=-, accuracy=1.0
# ID=21, predicted=-, true=-, accuracy=1.0
# ID=22, predicted=-, true=-, accuracy=1.0
# ID=23, predicted=-, true=-, accuracy=1.0
# ID=24, predicted=+, true=+, accuracy=1.0
# ID=25, predicted=-, true=-, accuracy=1.0
# ID=26, predicted=-, true=-, accuracy=1.0
# ID=27, predicted=+, true=+, accuracy=1.0
# ID=28, predicted=+, true=+, accuracy=1.0
# ID=29, predicted=-, true=-, accuracy=1.0
# ID=30, predicted=-, true=-, accuracy=1.0
# ID=31, predicted=+, true=+, accuracy=1.0
# ID=32, predicted=+, true=+, accuracy=1.0
# ID=33, predicted=+, true=+, accuracy=1.0
# ID=34, predicted=-, true=-, accuracy=1.0
# ID=35, predicted=+, true=+, accuracy=1.0
# ID=36, predicted=+, true=+, accuracy=1.0
# ID=37, predicted=+, true=+, accuracy=1.0
# ID=38, predicted=-, true=-, accuracy=1.0
# ID=39, predicted=+, true=+, accuracy=1.0
# ID=40, predicted=+, true=+, accuracy=1.0
# ID=41, predicted=+, true=+, accuracy=1.0
# ID=42, predicted=-, true=-, accuracy=1.0
# ID=43, predicted=-, true=-, accuracy=1.0
# ID=44, predicted=+, true=+, accuracy=1.0
# ID=45, predicted=-, true=-, accuracy=1.0
# ID=46, predicted=+, true=+, accuracy=1.0
# ID=47, predicted=-, true=-, accuracy=1.0
# ID=48, predicted=-, true=-, accuracy=1.0
# ID=49, predicted=-, true=-, accuracy=1.0
# ID=50, predicted=-, true=-, accuracy=1.0
# ID=51, predicted=-, true=-, accuracy=1.0
# ID=52, predicted=-, true=-, accuracy=1.0
# ID=53, predicted=-, true=-, accuracy=1.0
# ID=54, predicted=+, true=+, accuracy=1.0
# ID=55, predicted=+, true=+, accuracy=1.0
# ID=56, predicted=-, true=-, accuracy=1.0
# ID=57, predicted=+, true=+, accuracy=1.0
# ID=58, predicted=-, true=-, accuracy=1.0
# ID=59, predicted=+, true=+, accuracy=1.0
# ID=60, predicted=-, true=-, accuracy=1.0
# ID=61, predicted=+, true=+, accuracy=1.0
# ID=62, predicted=+, true=+, accuracy=1.0
# ID=63, predicted=+, true=+, accuracy=1.0
# ID=64, predicted=-, true=-, accuracy=1.0
# ID=65, predicted=+, true=+, accuracy=1.0
# ID=66, predicted=+, true=+, accuracy=1.0
# ID=67, predicted=+, true=+, accuracy=1.0
# ID=68, predicted=+, true=+, accuracy=1.0
# ID=69, predicted=+, true=+, accuracy=1.0
# ID=70, predicted=-, true=-, accuracy=1.0
# ID=71, predicted=+, true=+, accuracy=1.0
# ID=72, predicted=+, true=+, accuracy=1.0
# ID=73, predicted=-, true=-, accuracy=1.0
# ID=74, predicted=-, true=-, accuracy=1.0
# ID=75, predicted=-, true=-, accuracy=1.0
# ID=76, predicted=-, true=-, accuracy=1.0
# ID=77, predicted=+, true=+, accuracy=1.0
# ID=78, predicted=+, true=+, accuracy=1.0
# ID=79, predicted=+, true=+, accuracy=1.0
# ID=80, predicted=-, true=-, accuracy=1.0
# ID=81, predicted=+, true=+, accuracy=1.0
# ID=82, predicted=+, true=+, accuracy=1.0
# ID=83, predicted=-, true=-, accuracy=1.0
# ID=84, predicted=-, true=-, accuracy=1.0
# ID=85, predicted=+, true=+, accuracy=1.0
# ID=86, predicted=-, true=-, accuracy=1.0
# ID=87, predicted=+, true=+, accuracy=1.0
# ID=88, predicted=+, true=+, accuracy=1.0
# ID=89, predicted=+, true=+, accuracy=1.0
# ID=90, predicted=+, true=+, accuracy=1.0
# ID=91, predicted=+, true=+, accuracy=1.0
# ID=92, predicted=+, true=+, accuracy=1.0
# ID=93, predicted=+, true=+, accuracy=1.0
# ID=94, predicted=-, true=-, accuracy=1.0
# ID=95, predicted=-, true=-, accuracy=1.0
# ID=96, predicted=+, true=+, accuracy=1.0
# ID=97, predicted=+, true=+, accuracy=1.0
# ID=98, predicted=-, true=-, accuracy=1.0
# ID=99, predicted=-, true=-, accuracy=1.0
# ID=100, predicted=-, true=-, accuracy=1.0
# ID=101, predicted=-, true=-, accuracy=1.0
# ID=102, predicted=+, true=+, accuracy=1.0
# ID=103, predicted=+, true=+, accuracy=1.0
# ID=104, predicted=-, true=-, accuracy=1.0
# ID=105, predicted=+, true=+, accuracy=1.0
# ID=106, predicted=-, true=-, accuracy=1.0
# ID=107, predicted=+, true=+, accuracy=1.0
# ID=108, predicted=+, true=+, accuracy=1.0
# ID=109, predicted=-, true=-, accuracy=1.0
# ID=110, predicted=+, true=+, accuracy=1.0
# ID=111, predicted=-, true=-, accuracy=1.0
# ID=112, predicted=+, true=+, accuracy=1.0
# ID=113, predicted=+, true=+, accuracy=1.0
# ID=114, predicted=-, true=-, accuracy=1.0
# ID=115, predicted=+, true=+, accuracy=1.0
# ID=116, predicted=-, true=-, accuracy=1.0
# ID=117, predicted=+, true=+, accuracy=1.0
# ID=118, predicted=+, true=+, accuracy=1.0
# ID=119, predicted=-, true=-, accuracy=1.0
# ID=120, predicted=+, true=+, accuracy=1.0
# ID=121, predicted=-, true=-, accuracy=1.0
# ID=122, predicted=-, true=-, accuracy=1.0
# ID=123, predicted=+, true=+, accuracy=1.0
# ID=124, predicted=-, true=-, accuracy=1.0
# ID=125, predicted=-, true=-, accuracy=1.0
# ID=126, predicted=-, true=-, accuracy=1.0
# ID=127, predicted=-, true=-, accuracy=1.0
# ID=128, predicted=-, true=-, accuracy=1.0
# ID=129, predicted=+, true=+, accuracy=1.0
# ID=130, predicted=+, true=+, accuracy=1.0
# ID=131, predicted=-, true=-, accuracy=1.0
# ID=132, predicted=-, true=-, accuracy=1.0
# ID=133, predicted=+, true=+, accuracy=1.0
# ID=134, predicted=-, true=-, accuracy=1.0
# ID=135, predicted=+, true=+, accuracy=1.0
# ID=136, predicted=+, true=+, accuracy=1.0
# ID=137, predicted=+, true=+, accuracy=1.0
# ID=138, predicted=+, true=+, accuracy=1.0

# %%
key_list[val_list.index(y_pred[i])]
key_list[val_list.index(Y_test_np[i])]
# Out:
# '-'

# %%
dot_data = StringIO()
export_graphviz(dtree, out_file=dot_data, feature_names=features)

(graph, ) = graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-12f4bf00767c> in <module>
#       2 export_graphviz(dtree, out_file=dot_data, feature_names=features)
#       3
# ----> 4 (graph, ) = graph_from_dot_data(dot_data.getvalue())
#       5
#       6 Image(graph.create_png())
#
# TypeError: cannot unpack non-iterable Dot object

# %%
data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
graph = pydotplus.graph_from_dot_data(data)
graph.write_png('mydecisiontree.png')

img=pltimg.imread('mydecisiontree.png')
imgplot = plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# InvocationException                       Traceback (most recent call last)
# <ipython-input-116-9e015a010f8f> in <module>
#       3 data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
#       4 graph = pydotplus.graph_from_dot_data(data)
# ----> 5 graph.write_png('mydecisiontree.png')
#       6
#       7 img=pltimg.imread('mydecisiontree.png')
#
# ~/.local/lib/python3.8/site-packages/pydotplus/graphviz.py in <lambda>(path, f, prog)
#    1808                 lambda path,
#    1809                 f=frmt,
# -> 1810                 prog=self.prog: self.write(path, format=f, prog=prog)
#    1811             )
#    1812
#
# ~/.local/lib/python3.8/site-packages/pydotplus/graphviz.py in write(self, path, prog, format)
#    1916
#    1917             else:
# -> 1918                 fobj.write(self.create(prog, format))
#    1919         finally:
#    1920             if close:
#
# ~/.local/lib/python3.8/site-packages/pydotplus/graphviz.py in create(self, prog, format)
#    1957             self.progs = find_graphviz()
#    1958             if self.progs is None:
# -> 1959                 raise InvocationException(
#    1960                     'GraphViz\'s executables not found')
#    1961
#
# InvocationException: GraphViz's executables not found

# %%
X
# Out:
#                       0                    1                    2  \
# 0   4490718362573361911  4490718362573361911 -7404424852448591058
# 1  -2676740378976765750 -9136553377069384097 -2982592360674226285
# 2   8933748828388314377 -4597296373632058273  4407503608492856959
# 3    791977096551959204   791977096551959204   791977096551959204
# 4  -6882805504916369731 -6882805504916369731 -6882805504916369731
# 5  -6909581010745064066 -6507645511936620701  7981904594856601136
# 6  -6909581010745064066 -6507645511936620701  7684623094215056312
# 7   4407503608492856959  4407503608492856959  1148050952648369185
# 8   3760937016863143709   416711177065541026  3760937016863143709
# 9    416711177065541026  3760937016863143709  3760937016863143709
# 10 -5785075571072087807  4373561955044163364  4373561955044163364
# 11   416711177065541026  3760937016863143709  3760937016863143709
# 12 -6882805504916369731 -6882805504916369731 -6882805504916369731
# 13  6555077351765809498 -5589702139716391005 -3357885245538806218
#
#                       3                    4                    5  \
# 0  -7404424852448591058 -7404424852448591058 -7404424852448591058
# 1  -7498108909844969144  2175558559696683320 -8209524759852795568
# 2   -259587875382742927  4407503608492856959 -5791700434221681987
# 3    791977096551959204 -6740235034813817007 -6740235034813817007
# 4  -6882805504916369731  7768849094150245557  7768849094150245557
# 5   1348990649697003057 -7048725897003535871  7981904594856601136
# 6   7684623094215056312  8183130906925149982  7684623094215056312
# 7   3360109286358883271  4407503608492856959 -4019845063120586880
# 8   3760937016863143709  3760937016863143709   416711177065541026
# 9   3760937016863143709  3760937016863143709  3760937016863143709
# 10  4373561955044163364  4373561955044163364  4373561955044163364
# 11   416711177065541026   416711177065541026   416711177065541026
# 12 -6882805504916369731 -3800987078880983697 -3800987078880983697
# 13  4373561955044163364 -2804101373299870428 -5589702139716391005
#
#                       6                    7                    8  \
# 0  -7404424852448591058 -7404424852448591058 -7404424852448591058
# 1  -4702714212917802719 -7882446205762079870 -2286399665810934823
# 2  -7365072675803794769  9011763202027281884  1148050952648369185
# 3  -6740235034813817007   791977096551959204   791977096551959204
# 4   7768849094150245557 -6882805504916369731 -6882805504916369731
# 5  -4973697082396205329  5512202178929594592  1348990649697003057
# 6   7684623094215056312  7684623094215056312  7684623094215056312
# 7   2687242648885028979 -8407729830575698768 -3975308071299683754
# 8   3760937016863143709   416711177065541026  3760937016863143709
# 9   3760937016863143709  3760937016863143709  3760937016863143709
# 10  4373561955044163364  4373561955044163364  4373561955044163364
# 11  3760937016863143709   416711177065541026  3760937016863143709
# 12 -6882805504916369731 -3800987078880983697 -6882805504916369731
# 13   761469653756172003 -2370930556527838790 -4724885436790413042
#
#                       9                   10                   11  \
# 0  -7404424852448591058  4490718362573361911  4490718362573361911
# 1  -2982592360674226285 -1493571753120511483 -5290001008272051979
# 2   6376491847452131179  8933748828388314377  2139684227677450256
# 3    791977096551959204   791977096551959204   791977096551959204
# 4  -6882805504916369731 -6882805504916369731 -6882805504916369731
# 5   1348990649697003057  7988915072978608376  1019684536580089379
# 6   7684623094215056312  7684623094215056312  1260652596936834499
# 7  -2523716639877762716 -5926034451964504467 -2220930714101502042
# 8   3760937016863143709  3760937016863143709   416711177065541026
# 9   3760937016863143709  3760937016863143709  3760937016863143709
# 10  4373561955044163364  4373561955044163364  4373561955044163364
# 11   416711177065541026   416711177065541026  3760937016863143709
# 12 -6882805504916369731 -6882805504916369731 -6882805504916369731
# 13 -6752478123020751310   761469653756172003  8862333951946258949
#
#                      12                   13
# 0  -7404424852448591058 -7404424852448591058
# 1   6288709760923704986  1421075108703845768
# 2  -2255138184035253019 -9164020745818011696
# 3    791977096551959204 -6740235034813817007
# 4  -6882805504916369731  7768849094150245557
# 5   1348990649697003057 -5267537966668745088
# 6  -6507645511936620701  7684623094215056312
# 7   1959108127624958837  8382265666546582444
# 8   3760937016863143709   416711177065541026
# 9   3760937016863143709   416711177065541026
# 10  4373561955044163364 -2224199336342107721
# 11   416711177065541026  3760937016863143709
# 12 -3800987078880983697 -6882805504916369731
# 13  4373561955044163364  7428172230227890856

# %%
dtree = DecisionTreeClassifier()
dtree = dtree.fit(X, y)
data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
graph = pydotplus.graph_from_dot_data(data)
graph.write_png('mydecisiontree.png')

img=pltimg.imread('mydecisiontree.png')
imgplot = plt.imshow(img)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-f7c4e97c8c95> in <module>
#       1 dtree = DecisionTreeClassifier()
# ----> 2 dtree = dtree.fit(X, y)
#       3 data = tree.export_graphviz(dtree, out_file=None, feature_names=features)
#       4 graph = pydotplus.graph_from_dot_data(data)
#       5 graph.write_png('mydecisiontree.png')
#
# NameError: name 'X' is not defined

# %%
mydict={}
i = 0
for column in 
for item in df[0]:
    if(i>0 and item in mydict):
        continue
    else:    
       i = i+1
       mydict[item] = i

k=[]
for item in df[0]:
    k.append(mydict[item])
